# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('scores_assault_final.csv', index_col = 0)
df
# Out:
#       score  train_time  len_buff
# game
# 1     441.0      2.5402      1892
# 2     672.0      2.8369      4009
# 3     735.0      4.2458      7361
# 4     672.0      3.3339      9874
# 5     546.0      2.9394     12168
# ...     ...         ...       ...
# 1352  462.0      7.5476    200000
# 1353  567.0      8.4249    200000
# 1354  630.0      6.1097    200000
# 1355  252.0      4.0440    200000
# 1356  630.0      7.8845    200000
#
# [1357 rows x 3 columns]

# %%
df['score'].rolling(window=400).mean().dropna().plot()
# Out:
# <AxesSubplot:xlabel='game'>

# %%
plt.figure(figsize=(30,6))
n = 500
plt.plot(df[:n]['score'].reset_index(drop= True), alpha = 0.7)
plt.plot(df[-1*n:]['score'].reset_index(drop=True), alpha = 0.7)

# %%
df['score'].plot(figsize = ((30,6)))
# Out:
# <AxesSubplot:xlabel='game'>

# %%
plt.scatter(df['score'], df['train_time'])
plt.xlabel('score')
plt.ylabel('train_time')
plt.show()

# %%
df['score'].hist()
# Out:
# <AxesSubplot:>

# %%
df['train_time'].hist()
# Out:
# <AxesSubplot:>
