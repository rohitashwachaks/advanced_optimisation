# %%
import pandas as pd

# %%
df = pd.read_csv('scores_assault_final.csv', index_col=0)[['score','train_time']]
df
# Out:
#       score  train_time
# game
# 1       441      2.5402
# 2       672      2.8369
# 3       735      4.2458
# 4       672      3.3339
# 5       546      2.9394
# ...     ...         ...
# 670     630     10.0135
# 671     357      6.5956
# 672     546      6.3132
# 673     672      9.1740
# 674     399      7.5135
#
# [674 rows x 2 columns]

# %%
from matplotlib import pyplot as plt

plt.scatter(df['score'], df['train_time'])
plt.ylabel('Training Time (s)')
plt.xlabel('Score')
plt.title('Scores vs Training Time')
plt.show()

# %%
df['score'].plot()
# Out:
# <AxesSubplot:xlabel='game'>

# %%
df['train_time'].plot()
# Out:
# <AxesSubplot:xlabel='game'>
